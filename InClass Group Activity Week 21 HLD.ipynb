# %% [markdown]
# ## Group Activity, Week 21, Heather Leighton-Dick

# %% [markdown]
# ### 1. Make sure you can get the API from class to work in Azure. Take a screenshot of it working and add the image to a jupyter notebook.

# %% [markdown]
# ![azureflaskapp.jpg](attachment:azureflaskapp.jpg)

# %% [markdown]
# ### 2. Loop through the API data in python using the /gdp/year endpoint for your API. What does it look like? Is there a way to alter the html page to simplify what you see?

# %% [markdown]
# I'm out of time to try these out, but:
#
# brainstorming:
# • .tabulate? or some method to get the data into a table rather than a list of tuples
#
# • reformat the json data so it drops the less interesting tuples from view (like 'obs_status' and 'decimal')
#
# html brainstorming:
# • make each tuple into its own paragraph
# • reformat the list of tuples so it's oriented vertically
